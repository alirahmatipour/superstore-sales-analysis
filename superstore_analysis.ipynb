# %% [markdown]
# ## Data Loading

# %%
# Load the dataset and preview the first rows
import pandas as pd
df = pd.read_csv('Sample-Superstore.csv', encoding='latin1')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
# Check the number of rows and columns
df.shape
# Out:
# (9994, 21)

# %% [markdown]
# ## Data Cleaning

# %%
# Inspect column types and check for missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
# Check for missing values in each column
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
# Check for duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Convert date columns to proper datetime format for time-based analysis
df['Order Date'] = pd.to_datetime(df['Order Date'])
df['Ship Date'] = pd.to_datetime(df['Ship Date'])
df.dtypes
# Out:
# Row ID                    int64
# Order ID                 object
# Order Date       datetime64[ns]
# Ship Date        datetime64[ns]
# Ship Mode                object
# Customer ID              object
# Customer Name            object
# Segment                  object
# Country                  object
# City                     object
# State                    object
# Postal Code               int64
# Region                   object
# Product ID               object
# Category                 object
# Sub-Category             object
# Product Name             object
# Sales                   float64
# Quantity                  int64
# Discount                float64
# Profit                  float64
# dtype: object

# %% [markdown]
# ## 1. Category & Sub-Category Profitability Analysis

# %%
# Calculate total sales and profit per category, then add a profit margin column
category_summary = df.groupby('Category')[['Sales', 'Profit']].sum()
category_summary['Profit Margin'] = category_summary['Profit'] / category_summary['Sales']
category_summary
# Out:
#                        Sales       Profit  Profit Margin
# Category
# Furniture        741999.7953   18451.2728       0.024867
# Office Supplies  719047.0320  122490.8008       0.170352
# Technology       836154.0330  145454.9481       0.173957

# %%
# Calculate total sales and profit per sub-category, add profit margin, sort by margin
subcategory_summary = df.groupby('Sub-Category')[['Sales', 'Profit']].sum()
subcategory_summary['Profit Margin'] = subcategory_summary['Profit'] / subcategory_summary['Sales']
subcategory_summary.sort_values('Profit Margin')
# Out:
#                     Sales      Profit  Profit Margin
# Sub-Category
# Tables        206965.5320 -17725.4811      -0.085645
# Bookcases     114879.9963  -3472.5560      -0.030228
# Supplies       46673.5380  -1189.0995      -0.025477
# Machines      189238.6310   3384.7569       0.017886
# Chairs        328449.1030  26590.1663       0.080957
# Storage       223843.6080  21278.8264       0.095061
# Phones        330007.0540  44515.7306       0.134893
# Furnishings    91705.1640  13059.1436       0.142404
# Binders       203412.7330  30221.7633       0.148574
# Appliances    107532.1610  18138.0054       0.168675
# Art            27118.7920   6527.7870       0.240711
# Accessories   167380.3180  41936.6357       0.250547
# Fasteners       3024.2800    949.5182       0.313965
# Copiers       149528.0300  55617.8249       0.371956
# Envelopes      16476.4020   6964.1767       0.422676
# Paper          78479.2060  34053.5693       0.433918
# ...

# %% [markdown]
# **Finding:** Furniture has a much lower profit margin (2.5%) compared to
# Office Supplies and Technology (both ~17%), despite similar sales volume.
# Digging into sub-categories reveals the cause: Tables (-8.6% margin) and
# Bookcases (-3.0% margin) are actually losing money, dragging down the
# entire Furniture category.

# %% [markdown]
# ## 2. Regional & State Profit Analysis

# %%
# Calculate total sales and profit per region, add profit margin, sort by profit
region_summary = df.groupby('Region')[['Sales', 'Profit']].sum()
region_summary['Profit Margin'] = region_summary['Profit'] / region_summary['Sales']
region_summary.sort_values('Profit')
# Out:
#                Sales       Profit  Profit Margin
# Region
# Central  501239.8908   39706.3625       0.079216
# South    391721.9050   46749.4303       0.119343
# East     678781.2400   91522.7800       0.134834
# West     725457.8245  108418.4489       0.149448

# %%
# Calculate total sales and profit per state, add profit margin, sort by profit
state_summary = df.groupby('State')[['Sales', 'Profit']].sum()
state_summary['Profit Margin'] = state_summary['Profit'] / state_summary['Sales']
state_summary.sort_values('Profit').head(10)
# Out:
#                       Sales      Profit  Profit Margin
# State
# Texas           170188.0458 -25729.3563      -0.151182
# Ohio             78258.1360 -16971.3766      -0.216864
# Pennsylvania    116511.9140 -15559.9603      -0.133548
# Illinois         80166.1010 -12607.8870      -0.157272
# North Carolina   55603.1640  -7490.9122      -0.134721
# Colorado         32108.1180  -6527.8579      -0.203309
# Tennessee        30661.8730  -5341.6936      -0.174213
# Arizona          35282.0010  -3427.9246      -0.097158
# Florida          89473.7080  -3399.3017      -0.037992
# Oregon           17431.1500  -1190.4705      -0.068296

# %%
# Calculate total sales and profit per city (grouped with state to avoid mixing same-name cities), showing the 10 worst-performing cities
city_summary = df.groupby(['State', 'City'])[['Sales', 'Profit']].sum()
city_summary['Profit Margin'] = city_summary['Profit'] / city_summary['Sales']
city_summary.sort_values('Profit').head(10)
# Out:
#                                    Sales      Profit  Profit Margin
# State          City
# Pennsylvania   Philadelphia  109077.0130 -13837.7674      -0.126862
# Texas          Houston        64504.7604 -10153.5485      -0.157408
#                San Antonio    21843.5280  -7299.0502      -0.334152
# Ohio           Lancaster       8202.6250  -7149.6180      -0.871626
# Illinois       Chicago        48539.5410  -6654.5688      -0.137096
# North Carolina Burlington     12681.2820  -5894.5269      -0.464821
# Colorado       Louisville      5070.4160  -3406.2095      -0.671781
# Texas          Dallas         20131.9322  -2846.5257      -0.141394
# Arizona        Phoenix        11000.2570  -2790.8832      -0.253711
# Florida        Jacksonville   39133.3280  -2445.6608      -0.062496

# %% [markdown]
# **Finding:** Texas has the largest absolute loss (-$25,729), while Ohio has
# the worst relative performance (-21.7% profit margin). Drilling down to the
# city level reveals that Ohio's poor performance is driven almost entirely by
# one city, Lancaster, which has an extreme -87.2% profit margin — showing
# that state-level losses can be concentrated in just a few locations rather
# than spread evenly.

# %% [markdown]
# ## 3. Discount vs Profitability Analysis

# %%
# Calculate average discount and profit for each sub-category, sorted by discount (highest first)
discount_analysis = df.groupby('Sub-Category')[['Discount', 'Profit']].mean()
discount_analysis.sort_values('Discount', ascending=False)
# Out:
#               Discount      Profit
# Sub-Category
# Binders       0.372292   19.843574
# Machines      0.306087   29.432669
# Tables        0.261285  -55.565771
# Bookcases     0.211140  -15.230509
# Chairs        0.170178   43.095894
# Appliances    0.166524   38.922758
# Copiers       0.161765  817.909190
# Phones        0.154556   50.073938
# Furnishings   0.138349   13.645918
# Fasteners     0.082028    4.375660
# Envelopes     0.080315   27.418019
# Accessories   0.078452   54.111788
# Supplies      0.076842   -6.258418
# Paper         0.074891   24.856620
# Art           0.074874    8.200737
# Storage       0.074704   25.152277
# Labels        0.068681   15.236962

# %% [markdown]
# **Finding:** Tables and Bookcases receive high average discounts (26% and
# 21%) and show negative average profit, confirming that heavy discounting
# hurts profitability for these sub-categories. However, this relationship
# isn't strictly linear — Binders receives the highest discount (37%) but
# remains profitable, suggesting the impact of discounting depends on each
# product's baseline profit margin.

# %% [markdown]
# ## 4. Sales Trend Over Time

# %%
# Extract year and month from Order Date, then calculate total monthly sales
monthly_sales = df.set_index('Order Date').resample('ME')['Sales'].sum()
monthly_sales
# Out:
# Order Date
# 2014-01-31     14236.8950
# 2014-02-28      4519.8920
# 2014-03-31     55691.0090
# 2014-04-30     28295.3450
# 2014-05-31     23648.2870
# 2014-06-30     34595.1276
# 2014-07-31     33946.3930
# 2014-08-31     27909.4685
# 2014-09-30     81777.3508
# 2014-10-31     31453.3930
# 2014-11-30     78628.7167
# 2014-12-31     69545.6205
# 2015-01-31     18174.0756
# 2015-02-28     11951.4110
# 2015-03-31     38726.2520
# 2015-04-30     34195.2085
# 2015-05-31     30131.6865
# 2015-06-30     24797.2920
# 2015-07-31     28765.3250
# 2015-08-31     36898.3322
# 2015-09-30     64595.9180
# 2015-10-31     31404.9235
# 2015-11-30     75972.5635
# 2015-12-31     74919.5212
# 2016-01-31     18542.4910
# 2016-02-29     22978.8150
# 2016-03-31     51715.8750
# 2016-04-30     38750.0390
# 2016-05-31     56987.7280
# 2016-06-30     40344.5340
# 2016-07-31     39261.9630
# 2016-08-31     31115.3743
# 2016-09-30     73410.0249
# 2016-10-31     59687.7450
# 2016-11-30     79411.9658
# ...

# %%
# Plot the monthly sales trend as a line chart
import matplotlib.pyplot as plt

monthly_sales.plot(kind='line', figsize=(12, 5), title='Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.show()

# %% [markdown]
# **Finding:** Monthly sales show a clear upward trend over the four-year period (2014–2017), with total sales roughly doubling from the first year to the last. There is also a strong seasonal pattern — sales consistently dip in January and peak toward the end of each year (November/December), likely driven by holiday shopping.

# %% [markdown]
# ## 5. Top Customers by Value

# %%
# Calculate total sales and profit per customer, showing the top 10 by sales
customer_summary = df.groupby('Customer Name')[['Sales', 'Profit']].sum()
customer_summary.sort_values('Sales', ascending=False).head(10)
# Out:
#                         Sales     Profit
# Customer Name
# Sean Miller         25043.050 -1980.7393
# Tamara Chand        19052.218  8981.3239
# Raymond Buch        15117.339  6976.0959
# Tom Ashbrook        14595.620  4703.7883
# Adrian Barton       14473.571  5444.8055
# Ken Lonsdale        14175.229   806.8550
# Sanjit Chand        14142.334  5757.4119
# Hunter Lopez        12873.298  5622.4292
# Sanjit Engle        12209.438  2650.6769
# Christopher Conant  12129.072  2177.0493

# %% [markdown]
# **Finding:** Nine of the top 10 customers by sales volume are also profitable for the company. However, the single highest-spending customer, Sean Miller ($25,043 in sales), is actually unprofitable (-$1,981), highlighting that high sales volume alone doesn't guarantee profitability — this ties back to the earlier finding about discount and product-category effects on margins.
